# %%
import string
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pickle
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import seaborn as sns

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import regularizers
from tensorflow.keras import metrics
from tensorflow.keras.utils import plot_model
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.text import text_to_word_sequence
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
df = pd.read_csv("./movies-data/combine_data.csv")
df.head()
# Out:
# C:\Users\vuhoa\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  belongs_to_collection    budget  \
# 0           0                      1  0.078947
# 1           1                      1  0.078947
# 2           2                      1  0.078947
# 3           3                      1  0.078947
# 4           4                      1  0.078947
#
#                               genres   id original_language  popularity  \
# 0  ['Animation', 'Comedy', 'Family']  862                en   21.946943
# 1  ['Animation', 'Comedy', 'Family']  862                en   21.946943
# 2  ['Animation', 'Comedy', 'Family']  862                en   21.946943
# 3  ['Animation', 'Comedy', 'Family']  862                en   21.946943
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10933460 entries, 0 to 10933459
# Data columns (total 25 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             int64
#  1   belongs_to_collection  int64
#  2   budget                 float64
#  3   genres                 object
#  4   id                     int64
#  5   original_language      object
#  6   popularity             float64
#  7   production_companies   object
#  8   production_countries   object
#  9   release_date           object
#  10  revenue                float64
#  11  runtime                float64
#  12  status                 object
#  13  title                  object
#  14  vote_average           float64
#  15  vote_count             float64
#  16  release_year           object
#  17  profit                 float64
#  18  weighted_rating        float64
#  19  cast                   object
#  20  director               object
# ...

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10933460 entries, 0 to 10933459
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   belongs_to_collection  int64
#  1   budget                 float64
#  2   genres                 object
#  3   id                     int64
#  4   original_language      object
#  5   popularity             float64
#  6   production_companies   object
#  7   production_countries   object
#  8   release_date           object
#  9   revenue                float64
#  10  runtime                float64
#  11  status                 object
#  12  title                  object
#  13  vote_average           float64
#  14  vote_count             float64
#  15  release_year           object
#  16  profit                 float64
#  17  weighted_rating        float64
#  18  cast                   object
#  19  director               object
#  20  keywords               object
# ...

# %%
df.isna().any()
# Out:
# belongs_to_collection    False
# budget                    True
# genres                   False
# id                       False
# original_language        False
# popularity               False
# production_companies     False
# production_countries     False
# release_date             False
# revenue                   True
# runtime                  False
# status                   False
# title                    False
# vote_average             False
# vote_count               False
# release_year             False
# profit                    True
# weighted_rating          False
# cast                      True
# director                  True
# keywords                 False
# userId                   False
# rating                   False
# timestamp                False
# dtype: bool

# %%
df.isna().sum()
# Out:
# belongs_to_collection          0
# budget                   4623343
# genres                         0
# id                             0
# original_language              0
# popularity                     0
# production_companies           0
# production_countries           0
# release_date                   0
# revenue                  4820993
# runtime                        0
# status                         0
# title                          0
# vote_average                   0
# vote_count                     0
# release_year                   0
# profit                   5534531
# weighted_rating                0
# cast                        4940
# director                    1716
# keywords                       0
# userId                         0
# rating                         0
# timestamp                      0
# dtype: int64

# %%
numerical_data = ['id', 'popularity',
                    'vote_average', 'vote_count', 'weighted_rating', 'userId', 'rating']
categorical_data = ['original_language', 'release_date', 'release_year', 'status', 'title', 'director']
list_data = ['genres', 'production_countries', 'production_companies']
df[numerical_data].hist(bins= 150, figsize=(20,15))
plt.show()
# Out:
# C:\Users\vuhoa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
for col in numerical_data:
    sns.distplot(df[col], kde=True)
    plt.show()
# Out:
# C:\Users\vuhoa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\vuhoa\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for col in numerical_data:
    sns.boxplot(x=df[col])
    plt.show()

# %%
for col in categorical_data:
    print('-'*50)
    print(f'The column name is: {col}')
    print(df[col].value_counts())
# Out:
# --------------------------------------------------
# The column name is: original_language
# en          8106765
# fr           860347
# de           715541
# ja           214326
# es           209808
# ru           137350
# it           122282
# hi            98375
# da            59642
# nl            58046
# sv            56222
# fi            48448
# pl            29885
# ko            29073
# zh            27844
# mn            25633
# cs            18890
# bs            18283
# zu            17526
# th            15567
# fa            15320
# he            14034
# pt            13833
# cn             7320
# ro             4822
# xx             2797
# bn             2199
# tr              631
# no              573
# hu              458
# ta              312
# ca              216
# sr              207
# el              164
# tl              157
# uk              151
# af               99
# sk               99
# is               82
# id               41
# wo               34
# ...

# %%
for label in categorical_data:
    if(label is not 'release_date'):
       sns.barplot(x= df[label].value_counts()[:10].index,
           y= df[label].value_counts()[:10].values)
       plt.xlabel(label)
       plt.xticks(rotation=60)
       plt.ylabel("Frequency")
       plt.title('Show of {} Bar Plot'.format(label))
       plt.show()
# Out:
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\vuhoa\AppData\Local\Temp/ipykernel_12220/2226666323.py:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if(label is not 'release_date'):

# %%
df['release_year'].value_counts()[:100].index
# Out:
# Index([  2007.0,   2006.0,   2003.0,   2004.0,   2000.0,   2005.0,   2001.0,
#          2002.0,   1999.0,   1997.0,   1994.0,   1993.0,   1988.0,   1992.0,
#          1989.0,   1972.0,   1998.0,   1990.0,   1991.0,   1968.0,   1996.0,
#          1995.0,   1983.0,   1967.0,   2008.0,   1982.0,   1955.0,   1975.0,
#          1964.0,   1958.0,   1974.0,   1971.0,   1966.0,   1987.0,   1979.0,
#          1962.0,   1985.0,   1973.0,   1986.0,   1935.0,   1984.0,   1946.0,
#          1956.0,   1940.0,   1977.0,   1960.0,   1928.0,   2009.0,   2012.0,
#          1945.0,   1981.0,   1961.0,   1965.0,   2011.0,   1937.0,   1933.0,
#          1969.0,   1978.0,   1948.0,   1953.0,   1963.0,   1980.0,   1952.0,
#          1954.0,   1959.0,   1927.0,   1950.0,   1970.0,   1924.0,   1942.0,
#          1931.0,   1976.0,   1936.0,   1932.0,   1929.0,   1949.0, '2006.0',
#          1939.0,   1944.0,   2010.0,   1957.0,   1922.0,   1896.0,   1919.0,
# ...

# %%
sns.barplot(x= df['release_year'].value_counts()[:10].index,
           y= df['release_year'].value_counts()[:10].values)

plt.xlabel('Release_year')
plt.ylabel('Frequency')
plt.title('Show of Release Year Bar Plot')
plt.show()

# %%
def get_list(x, l=3):
    if isinstance(x, list):
        if len(x) > l:
            x = x[:l]
        return x

    return []

# %%
df['genres'] = df['genres'].apply(ast.literal_eval)
df['production_companies'] = df['production_companies'].apply(ast.literal_eval)
df['production_countries'] = df['production_countries'].apply(ast.literal_eval)
df['cast'] = df['cast'].apply(ast.literal_eval)
df['keywords'] = df['keywords'].apply(ast.literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12220/3807228484.py in <module>
#       2 df['production_companies'] = df['production_companies'].apply(ast.literal_eval)
#       3 df['production_countries'] = df['production_countries'].apply(ast.literal_eval)
# ----> 4 df['cast'] = df['cast'].apply(ast.literal_eval)
#       5 df['keywords'] = df['keywords'].apply(ast.literal_eval)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df['genres'] = df['genres'].apply(get_list)
df['production_companies'] = df['production_companies'].apply(get_list)
df['production_countries'] = df['production_countries'].apply(get_list)
df['cast'] = df['cast'].apply(get_list)
df['keywords'] = df['keywords'].apply(get_list)

# %%
import datetime
df['datetime_form'] = df['timestamp'].apply(lambda x: datetime.datetime.fromtimestamp(x))

# %%
df['datetime_form']
# Out:
# 0          1997-03-14 17:23:26
# 1          1999-12-24 21:15:12
# 2          1997-11-08 05:27:21
# 3          1997-03-27 05:27:06
# 4          1997-03-03 18:36:35
#                    ...
# 10933455   2014-07-21 00:53:05
# 10933456   2014-05-08 05:49:32
# 10933457   2016-06-28 12:07:29
# 10933458   2014-05-05 22:15:12
# 10933459   2016-08-22 10:11:59
# Name: datetime_form, Length: 10933460, dtype: datetime64[ns]

# %%
print("There is a total of {} users, with an average number of {} votes."
.format(df.userId.nunique(), round(df.shape[0]/df.userId.nunique()),2))
# Out:
# There is a total of 265458 users, with an average number of 41 votes.

# %%
tmp = df.userId.value_counts()[:5]
pd.DataFrame({'Id': tmp.index, 'Vote_counts': tmp.values})
# Out:
#        Id  Vote_counts
# 0   45811         2789
# 1    8659         2705
# 2  179792         2392
# 3  107720         2057
# 4  229879         1804

# %%
mean_rating = df.rating.mean()
mean_rating
# Out:
# 3.530109041419642

# %%
def build_plots_list(data, target=None):
    tmp = data[['title', target]].astype(str).drop_duplicates()
    tmp[target] = tmp[target].apply(ast.literal_eval)
    count_dict = {}
    for t in tmp[target]:
        for g in t:
            count_dict[g] = count_dict.get(g, 0) + 1
    count_data = pd.DataFrame.from_dict(data={target: count_dict.keys(), 'count': count_dict.values()})
    count_data = count_data.sort_values(ascending=False, by='count')
    sns.barplot(x= count_data[target][:10],
           y= count_data['count'][:10])

    plt.xlabel(target)
    plt.ylabel('Count')
    plt.title('Show of {} Bar Plot'.format(target))
    plt.xticks(rotation=90)
    plt.show()

# %%
pd.DataFrame((df.sort_values('vote_count',ascending=False)['title']).unique())[:10]
# Out:
#                                                    0
# 0                                          Inception
# 1                                    The Dark Knight
# 2                                       Interstellar
# 3                            Guardians of the Galaxy
# 4                                         Fight Club
# 5                                         The Matrix
# 6                                           Iron Man
# 7  The Lord of the Rings: The Fellowship of the Ring
# 8                                       Pulp Fiction
# 9                           The Shawshank Redemption

# %%
build_plots_list(data=df, target='genres')
build_plots_list(data=df, target='production_companies')
build_plots_list(data=df, target='production_countries')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8020/2480681190.py in <module>
# ----> 1 build_plots_list(data=df, target='genres')
#       2 build_plots_list(data=df, target='production_companies')
#       3 build_plots_list(data=df, target='production_countries')
#
# /tmp/ipykernel_8020/1719232658.py in build_plots_list(data, target)
#       8     count_data = pd.DataFrame.from_dict(data={target: count_dict.keys(), 'count': count_dict.values()})
#       9     count_data = count_data.sort_values(ascending=False, by='count')
# ---> 10     sns.barplot(x= count_data[target][:10],
#      11            y= count_data['count'][:10])
#      12
#
# ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
df.to_csv("./movies-data/combine-data-clean.csv")
